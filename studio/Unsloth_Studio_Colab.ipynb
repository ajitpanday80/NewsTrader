# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitpanday80/NewsTrader/blob/claude%2Fnews-sentiment-stock-signals-011CUtAiMCGgKeukBQ98MY2F/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 3933, done.
# remote: Counting objects: 100% (3933/3933), done.
# remote: Compressing objects: 100% (3735/3735), done.
# remote: Total 3933 (delta 223), reused 2059 (delta 163), pack-reused 0 (from 0)
# Receiving objects: 100% (3933/3933), 49.72 MiB | 22.78 MiB/s, done.
# Resolving deltas: 100% (223/223), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/16  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [=======-------------]  6/16  dependency overrides
#                  torch 2.11.0+cu128 detected -- installing torchao==0.17.0
#   deps           [====================] 16/16  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b10360-mix-87da1a2 (tag b10360)
#   whisper.cpp    prebuilt installed
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# On Colab, start() auto-opens a Cloudflare link and prints admin login credentials.
# Use the Cloudflare link above the ready card to open Studio (in-cell iframes often stay blank).
start()

# To skip the Cloudflare tunnel and try the in-notebook proxy iframe only:
# start(cloudflare=False)
# Out:
# 2026-08-14 08:01:52 [info     ] 🦥 Starting Unsloth Studio...
# {"timestamp": "2026-08-14T08:02:00.692179Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-08-14T08:02:00.717371Z", "level": "info", "event": "   Starting server..."}
# {"timestamp": "2026-08-14T08:02:00.718136Z", "level": "info", "event": "run_server startup begin api_only=False host=0.0.0.0 port=8888"}
# {"timestamp": "2026-08-14T08:02:00.758386Z", "level": "info", "event": "Imported FastAPI app in 1.8ms"}
# {"timestamp": "2026-08-14T08:02:00.762645Z", "level": "info", "event": "Ensured Unsloth directories in 44.5ms"}
# {"timestamp": "2026-08-14T08:02:00.853421Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 135.3ms"}
# INFO:     Started server process [1130]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-08-14T08:02:01.002653Z", "level": "info", "event": "Removing unsloth compiled cache: /root/.unsloth/studio/compiled_cache"}
# {"timestamp": "2026-08-14T08:02:01.267871Z", "level": "info", "event": "lifespan pre-auth setup completed in 266.6ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-08-14T08:02:01.404498Z", "level": "info", "event": "lifespan startup completed in 403.2ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://8.229.172.162:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-08-14T08:02:01.416463Z", "level": "info", "event": "Uvicorn startup hook completed in 698.3ms"}
# {"timestamp": "2026-08-14T08:02:01.419768Z", "level": "info", "event": "run_server uvicorn ready after 701.7ms"}
# {"timestamp": "2026-08-14T08:02:02.048174Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-08-14T08:02:03.584992Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1520.95}
# Hardware detected: CUDA -- Tesla T4
# {"timestamp": "2026-08-14T08:02:04.329223Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-08-14T08:02:16.231523Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.56}
# {"timestamp": "2026-08-14T08:02:17.525495Z", "level": "info", "event": "torch warm finished in 16121.2ms"}
# {"timestamp": "2026-08-14T08:02:18.385886Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-usw1b0-1j8hu2sj1zosn-b.us-west1-0.prod.colab.dev"}
# {"timestamp": "2026-08-14T08:02:18.386950Z", "level": "info", "event": "\ud83d\udd17 Shareable Cloudflare link: https://christ-lance-contributed-ministers.trycloudflare.com"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Shareable Unsloth Link is Ready!
#         </h2>
#         <a href="https://christ-lance-contributed-ministers.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px; cursor: pointer;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             This Cloudflare HTTPS link works from any device, so you can share it with anyone.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             🔗 <a href="https://christ-lance-contributed-ministers.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#                   style="color: #000000; text-decoration: underline; cursor: pointer;">https://christ-lance-contributed-ministers.trycloudflare.com</a>
#         </p>
#         <p style="color: #000000; margin: 16px 0 0 0; font-size: 20px; font-weight: 800;">
#             Password
#         </p>
#         <p style="margin: 6px 0 0 0;"><code style="display: inline-block; font-size: 24px;
#             font-weight: 800; text-decoration: underline; background: #f3f3f3;
#             padding: 4px 10px; border-radius: 6px;">WildlifeThirstilyOutdatedJet</code></p>
#         <p style="color: #666666; margin: 6px 0 0 0; font-size: 12px;">
#             Log in as <code>unsloth</code> with this password. Shown only in your
#             notebook session, and never included in the shared link.
#         </p>
#     </div>
# {"timestamp": "2026-08-14T08:02:28.978584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 3.08}
# {"timestamp": "2026-08-14T08:02:29.799857Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 64.22}
# {"timestamp": "2026-08-14T08:02:46.999559Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.67}
# {"timestamp": "2026-08-14T08:02:47.929851Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.51}
# {"timestamp": "2026-08-14T08:03:09.184443Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 77.51}
# {"timestamp": "2026-08-14T08:03:09.482674Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.18}
# {"timestamp": "2026-08-14T08:03:09.666280Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 2.95}
# {"timestamp": "2026-08-14T08:03:09.673782Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 5.91}
# {"timestamp": "2026-08-14T08:03:09.686854Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 11.86}
# {"timestamp": "2026-08-14T08:03:09.861062Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.6-27B-MTP-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/gemma-4-12b-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-MTP-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/gemma-4-26B-A4B-it-qat-GGUF', 'unsloth/Qwen-AgentWorld-35B-A3B-GGUF', 'unsloth/gemma-4-E4B-it-qat-GGUF', 'unsloth/Kimi-K3-GGUF', 'unsloth/Muse-Glimmer-30B-GGUF', 'unsloth/bge-small-en-v1.5-GGUF', 'unsloth/gemma-4-12B-it-qat-GGUF', 'unsloth/inkling-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/DeepSeek-V4-Flash-0731-GGUF', 'unsloth/gemma-4-31B-it-qat-GGUF', 'unsloth/Inkling-Small-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Ornith-1.0-35B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Laguna-S-2.1-GGUF', 'unsloth/gemma-4-E2B-it-qat-GGUF', 'unsloth/GLM-5.2-GGUF', 'unsloth/Kimi-K2.7-Code-GGUF', 'unsloth/Qwen3-30B-A3B-Thinking-2507-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3-8B-GGUF']"}
# {"timestamp": "2026-08-14T08:03:09.862501Z", "level": "info", "event": "Top hub models: ['unsloth/Qwen3.6-27B-NVFP4', 'unsloth/Qwen3.6-35B-A3B-NVFP4', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3.6-35B-A3B-NVFP4-Fast', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Qwen2.5-14B-Instruct', 'unsloth/Qwen3-Embedding-4B', 'unsloth/GLM-4.7-Flash', 'unsloth/bge-small-en-v1.5', 'unsloth/GLM-4.5-Air', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-14B-bnb-4bit', 'unsloth/Qwen3-VL-32B-Instruct-bnb-4bit', 'unsloth/gemma-4-26B-A4B-it-NVFP4', 'unsloth/Qwen3-0.6B', 'unsloth/llava-1.5-7b-hf-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/Qwen3-VL-2B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-1.7B', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-8B', 'unsloth/Qwen2.5-Coder-1.5B-Instruct', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen2.5-1.5B-Instruct-unsloth-bnb-4bit']"}
# {"timestamp": "2026-08-14T08:03:10.544588Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 856.24}
# {"timestamp": "2026-08-14T08:03:10.559372Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 13.71}
# {"timestamp": "2026-08-14T08:03:11.155848Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 11.7}
# {"timestamp": "2026-08-14T08:03:11.547373Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/hugging-face-token", "status_code": 200, "process_time_ms": 14.28}
# {"timestamp": "2026-08-14T08:03:13.093102Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 15.12}
# {"timestamp": "2026-08-14T08:03:13.110258Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 15.33}
# {"timestamp": "2026-08-14T08:03:13.785067Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-08-14T08:03:14.274721Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-08-14T08:03:14.276320Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-08-14T08:03:16.488341Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/openapi.json", "status_code": 200, "process_time_ms": 2009.23}
# {"timestamp": "2026-08-14T08:03:16.506684Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 16.51}
# {"timestamp": "2026-08-14T08:03:17.089311Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 595.05}
# {"timestamp": "2026-08-14T08:03:19.009914Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 11.68}
# {"timestamp": "2026-08-14T08:03:19.033030Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 249.17}
# {"timestamp": "2026-08-14T08:03:24.206259Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-08-14T08:03:24.223102Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/upload-limit", "status_code": 200, "process_time_ms": 43.7}
# {"timestamp": "2026-08-14T08:03:24.228187Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-14T08:03:24.232955Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 64.6}
# {"timestamp": "2026-08-14T08:03:24.250976Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 58.67}
# {"timestamp": "2026-08-14T08:03:24.253203Z", "level": "info", "event": "Cached dataset scan: roots=1 inspected=0 returned=0"}
# {"timestamp": "2026-08-14T08:03:24.255226Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 60.17}
# {"timestamp": "2026-08-14T08:03:24.259916Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 95.44}
# {"timestamp": "2026-08-14T08:03:26.222887Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-08-14T08:03:26.547266Z", "level": "info", "event": "Cached dataset scan: roots=1 inspected=0 returned=0"}
# {"timestamp": "2026-08-14T08:03:26.550323Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 12.71}
# {"timestamp": "2026-08-14T08:03:26.553056Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 8.92}
# {"timestamp": "2026-08-14T08:03:26.613752Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 6.49}
# {"timestamp": "2026-08-14T08:03:26.617790Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-14T08:03:26.619463Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 7.43}
# {"timestamp": "2026-08-14T08:03:26.721532Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 10.41}
# {"timestamp": "2026-08-14T08:03:37.700197Z", "level": "info", "event": "Getting model config for: unsloth/Qwen3.5-9B"}
# {"timestamp": "2026-08-14T08:03:37.709297Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# {"timestamp": "2026-08-14T08:03:38.510918Z", "level": "info", "event": "Model config result for unsloth/Qwen3.5-9B: is_vision=True, is_embedding=False, audio_type=None, audio_type_known=True, is_lora=False, max_position_embeddings=262144"}
# {"timestamp": "2026-08-14T08:03:38.595598Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-9B", "status_code": 200, "process_time_ms": 982.74}
# {"timestamp": "2026-08-14T08:03:39.129441Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.4}
# {"timestamp": "2026-08-14T08:03:49.760308Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.86}
# {"timestamp": "2026-08-14T08:04:00.441896Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.19}
# {"timestamp": "2026-08-14T08:04:01.222432Z", "level": "info", "event": "Getting model config for: unsloth/Qwen3.5-9B"}
# {"timestamp": "2026-08-14T08:04:01.444953Z", "level": "info", "event": "Model config result for unsloth/Qwen3.5-9B: is_vision=True, is_embedding=False, audio_type=None, audio_type_known=True, is_lora=False, max_position_embeddings=262144"}
# {"timestamp": "2026-08-14T08:04:01.530321Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-9B", "status_code": 200, "process_time_ms": 355.05}
# {"timestamp": "2026-08-14T08:04:01.715935Z", "level": "info", "event": "Cached model scan: inspected=1 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-14T08:04:01.725211Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 50.33}
# {"timestamp": "2026-08-14T08:04:01.733215Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 23.32}
# {"timestamp": "2026-08-14T08:04:01.740167Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 56.06}
# {"timestamp": "2026-08-14T08:04:01.741748Z", "level": "info", "event": "Cached dataset scan: roots=1 inspected=1 returned=0"}
# {"timestamp": "2026-08-14T08:04:01.745635Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 31.59}
# {"timestamp": "2026-08-14T08:04:01.980904Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 302.56}
# {"timestamp": "2026-08-14T08:04:11.077135Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.47}
# {"timestamp": "2026-08-14T08:04:21.734277Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.82}
# {"timestamp": "2026-08-14T08:04:32.347111Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.88}
# {"timestamp": "2026-08-14T08:04:42.995215Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.58}
# {"timestamp": "2026-08-14T08:04:49.686180Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.91}
# {"timestamp": "2026-08-14T08:04:49.961387Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 8.88}
# {"timestamp": "2026-08-14T08:04:53.679027Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.5}
# [08:04:54] [INFO] ✅ Validation passed
# {"timestamp": "2026-08-14T08:04:54.800721Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/data-recipe/validate", "status_code": 200, "process_time_ms": 1811.78}
# [08:04:55] [INFO] ✅ Validation passed
# {"timestamp": "2026-08-14T08:04:55.009311Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/data-recipe/validate", "status_code": 200, "process_time_ms": 3800.43}
# {"timestamp": "2026-08-14T08:04:56.473812Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/data-recipe/jobs", "status_code": 200, "process_time_ms": 23.35}
# {"timestamp": "2026-08-14T08:04:56.641369Z", "level": "error", "event": "data_recipe.jobs.start_conflict: job already running", "exception": "Traceback (most recent call last):\n  File \"/content/unsloth/studio/backend/routes/data_recipe/jobs.py\", line 452, in create_job\n    job_id = mgr.start(\n             ^^^^^^^^^^\n  File \"/content/unsloth/studio/backend/core/data_recipe/jobs/manager.py\", line 155, in start\n    raise RuntimeError(\"job already running\")\nRuntimeError: job already running"}
# | Traceback (most recent call last):
# |   File "/content/unsloth/studio/backend/routes/data_recipe/jobs.py", line 452, in create_job
# |     job_id = mgr.start(
# |              ^^^^^^^^^^
# |   File "/content/unsloth/studio/backend/core/data_recipe/jobs/manager.py", line 155, in start
# |     raise RuntimeError("job already running")
# | RuntimeError: job already running
# {"timestamp": "2026-08-14T08:04:56.647024Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/data-recipe/jobs", "status_code": 409, "process_time_ms": 11.46}
# {"timestamp": "2026-08-14T08:04:58.092830Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/data-recipe/jobs/11028dfed70b40f2be352997358343ec/status", "status_code": 200, "process_time_ms": 5.23}
# {"timestamp": "2026-08-14T08:05:01.257523Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/data-recipe/jobs/11028dfed70b40f2be352997358343ec/status", "status_code": 200, "process_time_ms": 8.42}
# {"timestamp": "2026-08-14T08:05:04.132280Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/data-recipe/jobs/11028dfed70b40f2be352997358343ec/status", "status_code": 200, "process_time_ms": 3.47}
# {"timestamp": "2026-08-14T08:05:06.883282Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.58}
# {"timestamp": "2026-08-14T08:05:08.135150Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.7}
# {"timestamp": "2026-08-14T08:05:17.646339Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.47}
# {"timestamp": "2026-08-14T08:05:29.518209Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.54}
# {"timestamp": "2026-08-14T08:05:30.047071Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/data-recipe/jobs/11028dfed70b40f2be352997358343ec/events", "status_code": 200, "process_time_ms": 31951.25}
# {"timestamp": "2026-08-14T08:05:40.169189Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.42}
# {"timestamp": "2026-08-14T08:05:50.815059Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.64}
# {"timestamp": "2026-08-14T08:05:56.507003Z", "level": "info", "event": "Getting model config for: unsloth/Qwen3.5-9B"}
# {"timestamp": "2026-08-14T08:05:56.713387Z", "level": "info", "event": "Model config result for unsloth/Qwen3.5-9B: is_vision=True, is_embedding=False, audio_type=None, audio_type_known=True, is_lora=False, max_position_embeddings=262144"}
# {"timestamp": "2026-08-14T08:05:56.798012Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-9B", "status_code": 200, "process_time_ms": 351.63}
# {"timestamp": "2026-08-14T08:05:56.954181Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 6.33}
# {"timestamp": "2026-08-14T08:05:56.964756Z", "level": "info", "event": "Cached dataset scan: roots=1 inspected=1 returned=0"}
# {"timestamp": "2026-08-14T08:05:56.966134Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 15.65}
# {"timestamp": "2026-08-14T08:06:02.088304Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.39}
# {"timestamp": "2026-08-14T08:06:05.860403Z", "level": "info", "event": "Checking format for dataset: AI4Math/MathVista"}
# {"timestamp": "2026-08-14T08:06:06.410318Z", "level": "info", "event": "torchcodec is installed but unusable (Could not load libtorchcodec. Likely causes:\n          1. FFmpeg is not properly installed in your environment. We support\n             versions 4, 5, 6, 7, and 8, and we attempt to load libtorchcodec\n             for each of those versions. Errors for versions not installed on\n             your system are expected; only the error for your installed FFmpeg\n             version is relevant. On Windows, ensure you've installed the\n             \"full-shared\" version which ships DLLs.\n          2. The PyTorch version (2.11.0+cu128) is not compatible with\n             this version of TorchCodec. Refer to the version compatibility\n             table:\n             https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.\n          3. Another runtime dependency; see exceptions below.\n\n        The following exceptions were raised as we tried to load libtorchcodec:\n        \n[start of libtorchcodec loading traceback]\nFFmpeg version 8:\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/torch/_ops.py\", line 1503, in load_library\n    ctypes.CDLL(path)\n  File \"/usr/lib/python3.12/ctypes/__init__.py\", line 379, in __init__\n    self._handle = _dlopen(self._name, mode)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^\nOSError: libavutil.so.60: cannot open shared object file: No such file or directory\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-\n... [3778 chars omitted; raise UNSLOTH_STUDIO_MAX_EXCEPTION_CHARS to see it all] ...\n\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/torchcodec/_core/ops.py\", line 57, in load_torchcodec_shared_libraries\n    torch.ops.load_library(core_library_path)\n  File \"/usr/local/lib/python3.12/dist-packages/torch/_ops.py\", line 1505, in load_library\n    raise OSError(f\"Could not load this library: {path}\") from e\nOSError: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core4.so\n[end of libtorchcodec loading traceback].)"}
# {"timestamp": "2026-08-14T08:06:06.415851Z", "level": "info", "event": "Checking format for dataset: AI4Math/MathVista"}
# {"timestamp": "2026-08-14T08:06:06.453337Z", "level": "info", "event": "torchcodec is unusable; decoding dataset audio with soundfile"}
# {"timestamp": "2026-08-14T08:06:06.567269Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-08-14T08:06:06.567869Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-08-14T08:06:07.935786Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/datasets/check-format", "status_code": 400, "process_time_ms": 2079.34}
# {"timestamp": "2026-08-14T08:06:10.396096Z", "level": "info", "event": "Format check result: requires_mapping=False, format=simple_image_text, is_image=True"}
# {"timestamp": "2026-08-14T08:06:10.547642Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/datasets/check-format", "status_code": 200, "process_time_ms": 4140.86}
# {"timestamp": "2026-08-14T08:06:12.684054Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.98}
# {"timestamp": "2026-08-14T08:06:17.042566Z", "level": "info", "event": "Checking format for dataset: AI4Math/MathVista"}
# {"timestamp": "2026-08-14T08:06:17.242203Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-08-14T08:06:19.697610Z", "level": "info", "event": "Format check result: requires_mapping=False, format=simple_image_text, is_image=True"}
# {"timestamp": "2026-08-14T08:06:19.866402Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/datasets/check-format", "status_code": 200, "process_time_ms": 2827.71}
# {"timestamp": "2026-08-14T08:06:24.042182Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/models/remote-code-scan", "status_code": 200, "process_time_ms": 2247.24}
# {"timestamp": "2026-08-14T08:06:24.059379Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 8.58}
# {"timestamp": "2026-08-14T08:06:24.430102Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3.5-9B"}
# {"timestamp": "2026-08-14T08:06:24.838848Z", "level": "info", "event": "video.unloaded"}
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# {"timestamp": "2026-08-14T08:06:28.409139Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260814_080624_c462cbd2", "status_code": 404, "process_time_ms": 18.46}
# {"timestamp": "2026-08-14T08:06:28.498285Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 145.43}
# {"timestamp": "2026-08-14T08:06:31.068526Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260814_080624_c462cbd2", "status_code": 404, "process_time_ms": 3.55}
# {"timestamp": "2026-08-14T08:06:34.583361Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260814_080624_c462cbd2", "status_code": 404, "process_time_ms": 282.59}
# {"timestamp": "2026-08-14T08:06:38.054309Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260814_080624_c462cbd2", "status_code": 404, "process_time_ms": 30.69}
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# {"timestamp": "2026-08-14T08:06:40.110561Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260814_080624_c462cbd2", "status_code": 404, "process_time_ms": 32.13}
# {"timestamp": "2026-08-14T08:06:40.159366Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 21.31}
# {"timestamp": "2026-08-14T08:06:42.283148Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs/job_20260814_080624_c462cbd2", "status_code": 404, "process_time_ms": 8.78}
# {"timestamp": "2026-08-14T08:06:49.373307Z", "level": "warning", "event": "Falling back to all visible GPUs; model may not fit: model=unsloth/Qwen3.5-9B selected=[0] usable_gb=14.85 required_gb=15.514 multi_gpu_overhead=0.85"}
# {"timestamp": "2026-08-14T08:06:49.381020Z", "level": "info", "event": "Training subprocess started (pid=4552)"}
# {"timestamp": "2026-08-14T08:06:49.440503Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 25019.63}
# {"timestamp": "2026-08-14T08:06:49.773340Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 14.94}
# {"timestamp": "2026-08-14T08:06:51.584838Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 30.91}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
